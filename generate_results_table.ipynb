# %%
import os
import csv
import statistics

# Directory containing experiment folders
experiments_dir = "experiments"

# Collect rows for each table
parameters_rows = []  # For the parameters table
summary_rows = []     # For the summary table

# Keep track of all parameter keys seen across experiments
all_param_keys = set()

# New summary fields (except ASR) are expected in the main summary CSV.
summary_keys = [
    "Average Best Loss",
    "Std Best Loss",
    "Average Gradient Time",
    "Std Gradient Time",
    "Average Sampling Time",
    "Std Sampling Time",
    "Average PGD Time",
    "Std PGD Time",
    "Average Loss Time",
    "Std Loss Time",
    "Average Total Time",
    "Std Total Time",
]

# We map them to shorter column names and combine avg±std.
summary_column_map = {
    "Average Best Loss": "Loss",
    "Std Best Loss": "Loss",
    "Average Gradient Time": "Grad (s)",
    "Std Gradient Time": "Grad (s)",
    "Average Sampling Time": "Sampling (s)",
    "Std Sampling Time": "Sampling (s)",
    "Average PGD Time": "PGD (s)",
    "Std PGD Time": "PGD (s)",
    "Average Loss Time": "LossTime (s)",
    "Std Loss Time": "LossTime (s)",
    "Average Total Time": "Total (s)",
    "Std Total Time": "Total (s)",
}

# Final column order for the results table (no "k" column here).
final_result_keys = [
    "Experiment",
    "Loss",
    "Grad (s)",
    "Sampling (s)",
    "PGD (s)",
    "LossTime (s)",
    "Total (s)",
    "ASR (%)",    # Combined average ± std ASR
]
# Display headers for the summary table
final_result_display = [
    "Experiment",
    "Loss",
    "Grad (s)",
    "Sampling (s)",
    "PGD (s)",
    "LossTime (s)",
    "Total (s)",
    "ASR (\\%)",
]

def latex_escape(text: str) -> str:
    """Escape underscores and percent signs for LaTeX."""
    return text.replace("_", "\\_").replace("%", "\\%")

def format_numeric(value: str, param_name: str = "") -> str:
    """
    Parse and format numeric parameters:
      - For integer parameters (seed, iter, search_width, etc.), display as integer.
      - Otherwise, format as float with 4 decimals.
      - On failure, return the text with special characters escaped.
    """
    if value in ("True", "False"):
        return value
    if param_name.lower() in ("seed", "iter", "search_width", "min_search_width", "num_steps", "num_prompts", "k"):
        try:
            return str(int(float(value)))
        except ValueError:
            return latex_escape(value)
    try:
        float_val = float(value)
        return f"{float_val:.4f}"
    except ValueError:
        return latex_escape(value)

def combine_avg_std(avg_val: str, std_val: str) -> str:
    """
    Combine average and standard deviation values into a single string with ±.
    If either is missing or 'nan', return "0.0000±0.0000".
    """
    if (not avg_val) or (avg_val.lower() == "nan") or (not std_val) or (std_val.lower() == "nan"):
        return "0.0000±0.0000"
    try:
        avg_float = float(avg_val)
        std_float = float(std_val)
        return f"{avg_float:.4f}±{std_float:.4f}"
    except ValueError:
        return "0.0000±0.0000"

# Gather experiment folders in sorted order
experiment_folders = sorted(
    folder for folder in os.listdir(experiments_dir)
    if os.path.isdir(os.path.join(experiments_dir, folder))
)

# Process each experiment folder and assign IDs (temporary exp1, exp2, etc.)
for i, folder in enumerate(experiment_folders, start=1):
    exp_id = f"exp{i}"
    folder_path = os.path.join(experiments_dir, folder)

    # ------------------ PARAMETERS TABLE ------------------
    parameters = {}
    params_file = os.path.join(folder_path, "parameters.csv")
    if os.path.exists(params_file):
        with open(params_file, newline="") as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                param = row["Parameter"]
                if param == "debug_output":
                    continue
                value = row["Value"]
                parameters[param] = value
                all_param_keys.add(param)
    # ------------------ ADD "k" FROM EVALUATION (if available) ------------------
    eval_summary_file = os.path.join(folder_path, "evaluation", "summary.csv")
    k_value = "N/A"
    asr_values = []
    k_values = []
    if os.path.exists(eval_summary_file):
        with open(eval_summary_file, newline="") as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                try:
                    asr_values.append(float(row["ASR (%)"]))
                    k_values.append(int(row["total"]))
                except Exception:
                    continue
        if k_values:
            avg_k = round(statistics.mean(k_values))
            k_value = f"{avg_k}"
        parameters["k"] = k_value
        all_param_keys.add("k")
    else:
        parameters["k"] = "N/A"
        all_param_keys.add("k")
    
    param_row = {"Experiment": exp_id}
    param_row.update(parameters)
    parameters_rows.append(param_row)

    # ------------------ RESULTS (SUMMARY) TABLE ------------------
    summary = {}
    summary_file = os.path.join(folder_path, "summary.csv")
    if os.path.exists(summary_file):
        with open(summary_file, newline="") as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                metric = row["Metric"]
                value = row["Value"]
                summary[metric] = value

    # Use evaluation/summary.csv to extract ASR values.
    if os.path.exists(eval_summary_file):
        with open(eval_summary_file, newline="") as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                try:
                    asr_values.append(float(row["ASR (%)"]))
                except Exception:
                    continue
        if asr_values:
            avg_asr = statistics.mean(asr_values)
            std_asr = statistics.stdev(asr_values) if len(asr_values) > 1 else 0.0
            summary["ASR (%)"] = f"{avg_asr:.4f}±{std_asr:.4f}"
        else:
            summary["ASR (%)"] = "N/A"
    else:
        summary["ASR (%)"] = "N/A"

    summary_row = {"Experiment": exp_id}
    summary_row["Loss"] = combine_avg_std(
        summary.get("Average Best Loss", ""), summary.get("Std Best Loss", "")
    )
    summary_row["Grad (s)"] = combine_avg_std(
        summary.get("Average Gradient Time", ""), summary.get("Std Gradient Time", "")
    )
    summary_row["Sampling (s)"] = combine_avg_std(
        summary.get("Average Sampling Time", ""), summary.get("Std Sampling Time", "")
    )
    summary_row["PGD (s)"] = combine_avg_std(
        summary.get("Average PGD Time", ""), summary.get("Std PGD Time", "")
    )
    summary_row["LossTime (s)"] = combine_avg_std(
        summary.get("Average Loss Time", ""), summary.get("Std Loss Time", "")
    )
    summary_row["Total (s)"] = combine_avg_std(
        summary.get("Average Total Time", ""), summary.get("Std Total Time", "")
    )
    summary_row["ASR (%)"] = summary.get("ASR (%)", "N/A")
    summary_rows.append(summary_row)

# ----------------------------------------------------------------------------
# Sort the tables by the "model" parameter while preserving correct ordering of experiments
# ----------------------------------------------------------------------------
# Combine the two lists to ensure that the rows in both tables remain aligned.
combined_list = []
for p_row, s_row in zip(parameters_rows, summary_rows):
    combined_list.append({
        "Experiment": p_row["Experiment"],
        "params": p_row,
        "summary": s_row
    })

def sort_key(item):
    # Get the model value; default to empty string if not present.
    model_val = item["params"].get("model", "").strip().lower()
    # Custom ordering: llava experiments first, then gemma, then others.
    if model_val == "llava":
        group = 0
    elif model_val == "gemma":
        group = 1
    else:
        group = 2
    # Also extract the numeric part from the Experiment ID (if needed) for a stable tie break.
    exp_id = item["Experiment"]
    try:
        num = int(exp_id.replace("exp", ""))
    except Exception:
        num = 0
    return (group, num)

combined_list.sort(key=sort_key)

# Reassign experiment numbers in the sorted order so that they are sequential.
for new_index, item in enumerate(combined_list, start=1):
    new_exp_id = f"exp{new_index}"
    item["params"]["Experiment"] = new_exp_id
    item["summary"]["Experiment"] = new_exp_id

# Reassemble the sorted parameters_rows and summary_rows.
parameters_rows = [item["params"] for item in combined_list]
summary_rows = [item["summary"] for item in combined_list]

# ----------------------------------------------------------------------------
# Remove "seed" from parameters keys for table columns
# ----------------------------------------------------------------------------
all_param_keys.discard("seed")

# ----------------------------------------------------------------------------
# 1) TABLE FOR PARAMETERS
# ----------------------------------------------------------------------------
param_columns = ["Experiment"] + sorted(all_param_keys, key=lambda x: x.lower())

latex_params = (
    "\\begin{table}[ht]\n"
    "\\centering\n"
    "\\resizebox{\\textwidth}{!}{%\n"  # Wrap in \\resizebox
    "  \\begin{tabular}{" + "l" * len(param_columns) + "}\n"
    "  \\hline\n"
)

escaped_headers = [latex_escape(col) for col in param_columns]
latex_params += "  " + " & ".join(escaped_headers) + " \\\\\n"
latex_params += "  \\hline\n"

for row in parameters_rows:
    row_values = []
    for col in param_columns:
        val = row.get(col, "")
        val_formatted = format_numeric(val, param_name=col)
        row_values.append(val_formatted)
    latex_params += "  " + " & ".join(row_values) + " \\\\\n"

latex_params += (
    "  \\hline\n"
    "  \\end{tabular}\n"
    "} % end of resizebox\n"
    "\\caption{Experiment parameters.}\n"
    "\\label{tab:experiment_parameters}\n"
    "\\end{table}\n"
)

# ----------------------------------------------------------------------------
# 2) TABLE FOR RESULTS (SUMMARY)
# ----------------------------------------------------------------------------
latex_summary = (
    "\\begin{table}[ht]\n"
    "\\centering\n"
    "\\resizebox{\\textwidth}{!}{%\n"  # Wrap in \\resizebox
    "  \\begin{tabular}{" + "l" * len(final_result_display) + "}\n"
    "  \\hline\n"
)

latex_summary += "  " + " & ".join(final_result_display) + " \\\\\n"
latex_summary += "  \\hline\n"

for row in summary_rows:
    row_values = []
    for key in final_result_keys:
        val = row.get(key, "")
        if key in ["Grad (s)", "Sampling (s)", "PGD (s)", "LossTime (s)", "Total (s)", "Loss", "ASR (%)"]:
            val_formatted = latex_escape(val)
        else:
            val_formatted = format_numeric(val, param_name=key)
        row_values.append(val_formatted)
    latex_summary += "  " + " & ".join(row_values) + " \\\\\n"

latex_summary += (
    "  \\hline\n"
    "  \\end{tabular}\n"
    "} % end of resizebox\n"
    "\\caption{Summary of experiment results.}\n"
    "\\label{tab:experiment_summary}\n"
    "\\end{table}\n"
)

print("%% ========== TABLE: PARAMETERS ========== %%")
print(latex_params)
print("\n%% ========== TABLE: SUMMARY ========== %%")
print(latex_summary)
# Out:
# %% ========== TABLE: PARAMETERS ========== %%
# \begin{table}[ht]
# \centering
# \resizebox{\textwidth}{!}{%
#   \begin{tabular}{lllllllllllllll}
#   \hline
#   Experiment & alpha & dynamic\_search & eps & gcg\_attack & joint\_eval & k & min\_search\_width & model & name & num\_prompts & num\_steps & pgd\_after\_gcg & pgd\_attack & search\_width \\
#   \hline
#   exp1 & 4/255 & False & 64/255 & False & False & 25 & 0 & llava & Llava - PGD Only & 20 & 600 & False & True & 0 \\
#   exp2 & 0/255 & False & 0/255 & True & False & 25 & 512 & llava & Llava - GCG Only & 20 & 250 & False & False & 512 \\
#   exp3 & 4/255 & False & 64/255 & True & False & 25 & 0 & llava & Llava - PGD + GCG & 20 & 250 & False & True & 512 \\
#   exp4 & 4/255 & False & 64/255 & False & False & 25 & 0 & llava & Llava - PGD Only & 10 & 600 & False & True & 0 \\
#   exp5 & 0/255 & False & 8/255 & False & False & 25 & 0 & llava & Llava - Auto-PGD 2 & 10 & 600 & False & True & 0 \\
#   exp6 & 4/255 & False & 64/255 & True & False & 25 & 0 & llava & Llava - GCG + PGD & 20 & 250 & True & True & 512 \\
#   exp7 & 0/255 & False & 64/255 & False & False & 25 & 0 & llava & Llava - APGD Only & 5 & 600 & False & True & 0 \\
#   exp8 & 0/255 & False & 0/255 & True & False & 25 & 512 & llava & Llava - GCG Only & 5 & 250 & False & False & 512 \\
#   exp9 & 4/255 & False & 64/255 & True & False & 25 & 0 & llava & Llava - PGD + GCG (Long) & 20 & 600 & False & True & 64 \\
#   exp10 & 4/255 & False & 64/255 & True & True & 25 & 0 & llava & Llava - PGD + GCG & 20 & 250 & False & True & 512 \\
#   exp11 & 4/255 & False & 64/255 & True & False & 25 & 0 & llava & Llava - PGD + GCG (Long) & 20 & 600 & False & True & 512 \\
#   exp12 & 4/255 & True & 64/255 & True & False & 25 & 32 & llava & Llava - PGD + GCG (DS) & 20 & 600 & False & True & 128 \\
#   exp13 & 4/255 & True & 64/255 & True & True & 25 & 32 & gemma & Gemma - Joint Eval DS (Old prompt) & 10 & 250 & False & True & 512 \\
#   exp14 & 0/255 & True & 64/255 & True & True & 25 & 64 & gemma & Gemma - Joint Eval (New prompt, DS, APGD) & 5 & 250 & False & True & 512 \\
#   exp15 & 0/255 & False & 0/255 & True & False & 25 & 512 & gemma & Gemma - GCG Only & 5 & 250 & False & False & 512 \\
#   exp16 & 0/255 & False & 64/255 & False & False & 25 & 0 & gemma & Gemma - APGD Only & 5 & 600 & False & True & 0 \\
#   exp17 & 0/255 & False & 64/255 & True & False & 25 & 0 & gemma & Gemma - PGD + GCG & 5 & 250 & False & True & 512 \\
#   exp18 &  &  &  &  &  & N/A &  &  &  &  &  &  &  &  \\
#   exp19 &  &  &  &  &  & N/A &  &  &  &  &  &  &  &  \\
#   \hline
#   \end{tabular}
# } % end of resizebox
# \caption{Experiment parameters.}
# \label{tab:experiment_parameters}
# \end{table}
#
#
# %% ========== TABLE: SUMMARY ========== %%
# \begin{table}[ht]
# \centering
# \resizebox{\textwidth}{!}{%
#   \begin{tabular}{llllllll}
#   \hline
#   Experiment & Loss & Grad (s) & Sampling (s) & PGD (s) & LossTime (s) & Total (s) & ASR (\%) \\
#   \hline
#   exp1 & 0.0989±0.1397 & 0.2765±0.0091 & 0.0000±0.0000 & 0.0002±0.0000 & 0.2996±0.0145 & 0.5763±0.0229 & 81.6000±23.1791 \\
#   exp2 & 0.1062±0.0806 & 0.2188±0.0316 & 1.1156±1.2236 & 0.0000±0.0000 & 2.6441±0.9283 & 3.9785±2.1211 & 32.8000±30.3579 \\
#   exp3 & 0.1421±0.0564 & 0.3008±0.0158 & 0.1844±0.0032 & 0.0002±0.0000 & 2.6124±0.2390 & 2.9849±0.2400 & 80.8000±22.3941 \\
#   exp4 & 0.0824±0.0808 & 0.2897±0.0064 & 0.0000±0.0000 & 0.0002±0.0000 & 0.3171±0.0077 & 0.6070±0.0139 & 74.8000±23.1462 \\
#   exp5 & 0.4637±0.3825 & 0.5438±0.1082 & 0.0000±0.0000 & 0.0005±0.0000 & 0.5214±0.0994 & 1.0657±0.2065 & 54.0000±27.7280 \\
#   exp6 & 0.1366±0.0749 & 0.3438±0.0335 & 2.1943±1.3152 & 0.0002±0.0000 & 2.2037±0.7772 & 2.8230±1.3854 & 79.6000±24.7042 \\
#   exp7 & 0.0666±0.0543 & 0.5291±0.0823 & 0.0000±0.0000 & 0.0005±0.0000 & 0.5246±0.0639 & 1.0542±0.1450 & 80.0000±9.6148 \\
#   exp8 & 0.0707±0.0430 & 0.7518±0.1739 & 1.2879±0.0776 & 0.0000±0.0000 & 4.3684±0.4180 & 6.4081±0.6576 & 27.2000±22.6902 \\
#   exp9 & 0.1073±0.0634 & 0.3262±0.0107 & 0.4363±0.0044 & 0.0002±0.0000 & 1.1985±0.0734 & 1.9502±0.0834 & 82.2000±19.4478 \\
#   exp10 & 0.1292±0.1036 & 0.3205±0.0579 & 1.6192±1.4878 & 0.0003±0.0001 & 48.0748±14.6302 & 49.9650±16.1371 & 65.2000±33.3583 \\
#   exp11 & 0.0897±0.0678 & 0.4674±0.1113 & 2.4421±1.4711 & 0.0004±0.0002 & 5.1613±2.0784 & 7.9355±3.2707 & 82.0000±24.3900 \\
#   exp12 & 0.1073±0.0679 & 0.3434±0.0176 & 0.5269±0.0049 & 0.0002±0.0000 & 1.3032±0.0992 & 2.1640±0.1122 & 82.2000±17.6798 \\
#   exp13 & 0.1289±0.1084 & 0.3085±0.0174 & 0.9789±0.5938 & 0.0002±0.0000 & 26.8978±5.1844 & 28.1509±5.8241 & 0.0000±0.0000 \\
#   exp14 & 0.3597±0.2579 & 8.6789±1.0524 & 0.3440±0.2316 & 0.0006±0.0001 & 53.6737±6.2688 & 62.5025±7.0245 & 3.2000±6.7462 \\
#   exp15 & 0.4365±0.1334 & 8.5518±2.4024 & 0.4739±0.1587 & 0.0000±0.0000 & 10.6235±2.3119 & 19.6492±4.8394 & 1.6000±3.3731 \\
#   exp16 & 2.7391±0.5805 & 8.6915±1.3051 & 0.0000±0.0000 & 0.0005±0.0000 & 8.5592±1.3141 & 17.2512±2.6180 & 0.8000±1.6865 \\
#   exp17 & 1.2281±0.3340 & 8.7780±1.4517 & 0.9721±0.8142 & 0.0006±0.0001 & 19.9630±3.2994 & 29.5037±5.2152 & 0.0000±0.0000 \\
#   exp18 & 0.0000±0.0000 & 0.0000±0.0000 & 0.0000±0.0000 & 0.0000±0.0000 & 0.0000±0.0000 & 0.0000±0.0000 & N/A \\
#   exp19 & 0.0000±0.0000 & 0.0000±0.0000 & 0.0000±0.0000 & 0.0000±0.0000 & 0.0000±0.0000 & 0.0000±0.0000 & N/A \\
#   \hline
#   \end{tabular}
# } % end of resizebox
# \caption{Summary of experiment results.}
# \label{tab:experiment_summary}
# \end{table}

# %%
import os
import csv
import statistics

# Directory containing experiment folders
experiments_dir = "experiments"

# Collect rows for each table
parameters_rows = []  # For the parameters table
summary_rows = []     # For the summary table

# Keep track of all parameter keys seen across experiments
all_param_keys = set()

# Only the following summary fields will be used (loss and total time).
summary_keys = [
    "Average Best Loss",
    "Std Best Loss",
    "Average Total Time",
    "Std Total Time",
]

def latex_escape(text: str) -> str:
    """Escape underscores and percent signs for LaTeX."""
    return text.replace("_", "\\_").replace("%", "\\%")

def format_numeric(value: str, param_name: str = "") -> str:
    """
    Parse and format numeric parameters:
      - Convert "True"/"False" to check marks.
      - For integer parameters (seed, iter, search_width, etc.), display as integer.
      - Otherwise, format as float with 4 decimals.
      - On failure, return the text with special characters escaped.
    """
    if value == "True":
        return r"\cmark"
    if value == "False":
        return r"\xmark"
    if param_name.lower() in ("seed", "iter", "search_width", "min_search_width", "num_steps", "num_prompts", "k"):
        try:
            return str(int(float(value)))
        except ValueError:
            return latex_escape(value)
    try:
        float_val = float(value)
        return f"{float_val:.4f}"
    except ValueError:
        return latex_escape(value)

def combine_avg_std(avg_val: str, std_val: str, decimals: int = 4) -> str:
    """
    Combine average and standard deviation values into a single string with ±.
    If either is missing or 'nan', return a default string (e.g. "0.0000±0.0000").
    """
    default_str = f"{0:.{decimals}f}±{0:.{decimals}f}"
    if (not avg_val) or (avg_val.lower() == "nan") or (not std_val) or (std_val.lower() == "nan"):
        return default_str
    try:
        avg_float = float(avg_val)
        std_float = float(std_val)
        return f"{avg_float:.{decimals}f}±{std_float:.{decimals}f}"
    except ValueError:
        return default_str

# Gather experiment folders in sorted order
experiment_folders = sorted(
    folder for folder in os.listdir(experiments_dir)
    if os.path.isdir(os.path.join(experiments_dir, folder))
)

# Process each experiment folder and assign IDs (temporary exp1, exp2, etc.)
for i, folder in enumerate(experiment_folders, start=1):
    exp_id = f"exp{i}"
    folder_path = os.path.join(experiments_dir, folder)

    # ------------------ PARAMETERS TABLE ------------------
    parameters = {}
    params_file = os.path.join(folder_path, "parameters.csv")
    if os.path.exists(params_file):
        with open(params_file, newline="") as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                param = row["Parameter"]
                if param == "debug_output":
                    continue
                value = row["Value"]
                parameters[param] = value
                all_param_keys.add(param)
    # ------------------ ADD "k" FROM EVALUATION (if available) ------------------
    eval_summary_file = os.path.join(folder_path, "evaluation", "summary.csv")
    k_value = "N/A"
    asr_values = []
    k_values = []
    if os.path.exists(eval_summary_file):
        with open(eval_summary_file, newline="") as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                try:
                    asr_values.append(float(row["ASR (%)"]))
                    k_values.append(int(row["total"]))
                except Exception:
                    continue
        if k_values:
            avg_k = round(statistics.mean(k_values))
            k_value = f"{avg_k}"
        parameters["k"] = k_value
        all_param_keys.add("k")
    else:
        parameters["k"] = "N/A"
        all_param_keys.add("k")
    
    param_row = {"Experiment": exp_id}
    param_row.update(parameters)
    parameters_rows.append(param_row)

    # ------------------ RESULTS (SUMMARY) TABLE ------------------
    summary = {}
    summary_file = os.path.join(folder_path, "summary.csv")
    if os.path.exists(summary_file):
        with open(summary_file, newline="") as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                metric = row["Metric"]
                value = row["Value"]
                summary[metric] = value

    # Use evaluation/summary.csv to extract ASR values.
    if os.path.exists(eval_summary_file):
        with open(eval_summary_file, newline="") as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                try:
                    asr_values.append(float(row["ASR (%)"]))
                except Exception:
                    continue
        if asr_values:
            avg_asr = statistics.mean(asr_values)
            std_asr = statistics.stdev(asr_values) if len(asr_values) > 1 else 0.0
            # Format ASR with 2 decimals
            summary["ASR (%)"] = f"{avg_asr:.2f}±{std_asr:.2f}"
        else:
            summary["ASR (%)"] = "N/A"
    else:
        summary["ASR (%)"] = "N/A"

    summary_row = {"Experiment": exp_id}
    summary_row["Loss"] = combine_avg_std(
        summary.get("Average Best Loss", ""), summary.get("Std Best Loss", "")
    )
    summary_row["Total (s)"] = combine_avg_std(
        summary.get("Average Total Time", ""), summary.get("Std Total Time", "")
    )
    summary_row["ASR (%)"] = summary.get("ASR (%)", "N/A")
    summary_rows.append(summary_row)

# ----------------------------------------------------------------------------
# Sort the tables by the "model" parameter while preserving correct ordering of experiments
# ----------------------------------------------------------------------------
# Combine the two lists to ensure that the rows in both tables remain aligned.
combined_list = []
for p_row, s_row in zip(parameters_rows, summary_rows):
    combined_list.append({
        "Experiment": p_row["Experiment"],
        "params": p_row,
        "summary": s_row
    })

def sort_key(item):
    # Get the model value; default to empty string if not present.
    model_val = item["params"].get("model", "").strip().lower()
    # Custom ordering: llava experiments first, then gemma, then others.
    if model_val == "llava":
        group = 0
    elif model_val == "gemma":
        group = 1
    else:
        group = 2
    # Also extract the numeric part from the Experiment ID (if needed) for a stable tie break.
    exp_id = item["Experiment"]
    try:
        num = int(exp_id.replace("exp", ""))
    except Exception:
        num = 0
    return (group, num)

combined_list.sort(key=sort_key)

# Reassign experiment numbers in the sorted order so that they are sequential.
for new_index, item in enumerate(combined_list, start=1):
    new_exp_id = f"exp{new_index}"
    item["params"]["Experiment"] = new_exp_id
    item["summary"]["Experiment"] = new_exp_id

# Reassemble the sorted parameters_rows and summary_rows.
parameters_rows = [item["params"] for item in combined_list]
summary_rows = [item["summary"] for item in combined_list]

# ----------------------------------------------------------------------------
# Remove unwanted keys from parameters table.
# Exclude: "seed", "alpha", "eps", "num_prompts", "k", "pgd_after_gcg", "min_search_width", and "model"
exclude_keys = {"seed", "alpha", "eps", "num_prompts", "k", "pgd_after_gcg", "min_search_width", "model"}
all_param_keys = all_param_keys - exclude_keys

# ----------------------------------------------------------------------------
# 1) TABLE FOR PARAMETERS
# ----------------------------------------------------------------------------
param_columns = ["Experiment"] + sorted(all_param_keys, key=lambda x: x.lower())

latex_params = (
    "\\begin{table}[ht]\n"
    "\\centering\n"
    "\\resizebox{\\textwidth}{!}{%\n"  # Wrap in \\resizebox
    "  \\begin{tabular}{" + "l" * len(param_columns) + "}\n"
    "  \\hline\n"
)

escaped_headers = [latex_escape(col) for col in param_columns]
latex_params += "  " + " & ".join(escaped_headers) + " \\\\\n"
latex_params += "  \\hline\n"

for row in parameters_rows:
    row_values = []
    for col in param_columns:
        val = row.get(col, "")
        val_formatted = format_numeric(val, param_name=col)
        row_values.append(val_formatted)
    latex_params += "  " + " & ".join(row_values) + " \\\\\n"

latex_params += (
    "  \\hline\n"
    "  \\end{tabular}\n"
    "} % end of resizebox\n"
    "\\caption{Experiment parameters.}\n"
    "\\label{tab:experiment_parameters}\n"
    "\\end{table}\n"
)

# ----------------------------------------------------------------------------
# 2) TABLE FOR RESULTS (SUMMARY)
# ----------------------------------------------------------------------------
# Only include: Experiment, Loss, Total (s), and ASR (%)
final_result_keys = [
    "Experiment",
    "Loss",
    "Total (s)",
    "ASR (%)",
]
final_result_display = [
    "Experiment",
    "Loss",
    "Total (s)",
    "ASR (\\%)",
]

latex_summary = (
    "\\begin{table}[ht]\n"
    "\\centering\n"
    "\\resizebox{\\textwidth}{!}{%\n"  # Wrap in \\resizebox
    "  \\begin{tabular}{" + "l" * len(final_result_display) + "}\n"
    "  \\hline\n"
)

latex_summary += "  " + " & ".join(final_result_display) + " \\\\\n"
latex_summary += "  \\hline\n"

for row in summary_rows:
    row_values = []
    for key in final_result_keys:
        val = row.get(key, "")
        # For the Loss, Total (s), and ASR (%) columns, escape LaTeX if needed
        if key in ["Loss", "Total (s)", "ASR (%)"]:
            val_formatted = latex_escape(val)
        else:
            val_formatted = format_numeric(val, param_name=key)
        row_values.append(val_formatted)
    latex_summary += "  " + " & ".join(row_values) + " \\\\\n"

latex_summary += (
    "  \\hline\n"
    "  \\end{tabular}\n"
    "} % end of resizebox\n"
    "\\caption{Summary of experiment results.}\n"
    "\\label{tab:experiment_summary}\n"
    "\\end{table}\n"
)

print("%% ========== TABLE: PARAMETERS ========== %%")
print(latex_params)
print("\n%% ========== TABLE: SUMMARY ========== %%")
print(latex_summary)
# Out:
# %% ========== TABLE: PARAMETERS ========== %%
# \begin{table}[ht]
# \centering
# \resizebox{\textwidth}{!}{%
#   \begin{tabular}{llllllll}
#   \hline
#   Experiment & dynamic\_search & gcg\_attack & joint\_eval & name & num\_steps & pgd\_attack & search\_width \\
#   \hline
#   exp1 & \xmark & \xmark & \xmark & Llava - PGD Only & 600 & \cmark & 0 \\
#   exp2 & \xmark & \cmark & \xmark & Llava - GCG Only & 250 & \xmark & 512 \\
#   exp3 & \xmark & \cmark & \xmark & Llava - PGD + GCG & 250 & \cmark & 512 \\
#   exp4 & \xmark & \xmark & \xmark & Llava - PGD Only & 600 & \cmark & 0 \\
#   exp5 & \xmark & \xmark & \xmark & Llava - Auto-PGD 2 & 600 & \cmark & 0 \\
#   exp6 & \xmark & \cmark & \xmark & Llava - GCG + PGD & 250 & \cmark & 512 \\
#   exp7 & \xmark & \xmark & \xmark & Llava - APGD Only & 600 & \cmark & 0 \\
#   exp8 & \xmark & \cmark & \xmark & Llava - GCG Only & 250 & \xmark & 512 \\
#   exp9 & \xmark & \cmark & \xmark & Llava - PGD + GCG (Long) & 600 & \cmark & 64 \\
#   exp10 & \xmark & \cmark & \cmark & Llava - PGD + GCG & 250 & \cmark & 512 \\
#   exp11 & \xmark & \cmark & \xmark & Llava - PGD + GCG (Long) & 600 & \cmark & 512 \\
#   exp12 & \cmark & \cmark & \xmark & Llava - PGD + GCG (DS) & 600 & \cmark & 128 \\
#   exp13 & \cmark & \cmark & \cmark & Gemma - Joint Eval DS (Old prompt) & 250 & \cmark & 512 \\
#   exp14 & \cmark & \cmark & \cmark & Gemma - Joint Eval (New prompt, DS, APGD) & 250 & \cmark & 512 \\
#   exp15 & \xmark & \cmark & \xmark & Gemma - GCG Only & 250 & \xmark & 512 \\
#   exp16 & \xmark & \xmark & \xmark & Gemma - APGD Only & 600 & \cmark & 0 \\
#   exp17 & \xmark & \cmark & \xmark & Gemma - PGD + GCG & 250 & \cmark & 512 \\
#   exp18 &  &  &  &  &  &  &  \\
#   exp19 &  &  &  &  &  &  &  \\
#   \hline
#   \end{tabular}
# } % end of resizebox
# \caption{Experiment parameters.}
# \label{tab:experiment_parameters}
# \end{table}
#
#
# %% ========== TABLE: SUMMARY ========== %%
# \begin{table}[ht]
# \centering
# \resizebox{\textwidth}{!}{%
#   \begin{tabular}{llll}
#   \hline
#   Experiment & Loss & Total (s) & ASR (\%) \\
#   \hline
#   exp1 & 0.0989±0.1397 & 0.5763±0.0229 & 81.60±23.18 \\
#   exp2 & 0.1062±0.0806 & 3.9785±2.1211 & 32.80±30.36 \\
#   exp3 & 0.1421±0.0564 & 2.9849±0.2400 & 80.80±22.39 \\
#   exp4 & 0.0824±0.0808 & 0.6070±0.0139 & 74.80±23.15 \\
#   exp5 & 0.4637±0.3825 & 1.0657±0.2065 & 54.00±27.73 \\
#   exp6 & 0.1366±0.0749 & 2.8230±1.3854 & 79.60±24.70 \\
#   exp7 & 0.0666±0.0543 & 1.0542±0.1450 & 80.00±9.61 \\
#   exp8 & 0.0707±0.0430 & 6.4081±0.6576 & 27.20±22.69 \\
#   exp9 & 0.1073±0.0634 & 1.9502±0.0834 & 82.20±19.45 \\
#   exp10 & 0.1292±0.1036 & 49.9650±16.1371 & 65.20±33.36 \\
#   exp11 & 0.0897±0.0678 & 7.9355±3.2707 & 82.00±24.39 \\
#   exp12 & 0.1073±0.0679 & 2.1640±0.1122 & 82.20±17.68 \\
#   exp13 & 0.1289±0.1084 & 28.1509±5.8241 & 0.00±0.00 \\
#   exp14 & 0.3597±0.2579 & 62.5025±7.0245 & 3.20±6.75 \\
#   exp15 & 0.4365±0.1334 & 19.6492±4.8394 & 1.60±3.37 \\
#   exp16 & 2.7391±0.5805 & 17.2512±2.6180 & 0.80±1.69 \\
#   exp17 & 1.2281±0.3340 & 29.5037±5.2152 & 0.00±0.00 \\
#   exp18 & 0.0000±0.0000 & 0.0000±0.0000 & N/A \\
#   exp19 & 0.0000±0.0000 & 0.0000±0.0000 & N/A \\
#   \hline
#   \end{tabular}
# } % end of resizebox
# \caption{Summary of experiment results.}
# \label{tab:experiment_summary}
# \end{table}
